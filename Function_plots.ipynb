# %%
import sys
import numpy as np
import scipy as sp
import sklearn
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt
# %pylab inline
import ipywidgets as widgets
from IPython.utils.py3compat import annotate
from IPython.display import display
from ipywidgets import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from FIVOA import * #to access Point
from FIVOA.Functions import *
from FIVOA.Constraints import *
from FIVOA.Algorithms import *
from FIVOA.Drawing import *

# %%
def f0(x):
    return x * np.cos(x)

# %%
def f1(x):
    return np.square(x) - 4

# %%
def f2(x):
    #return np.square(x) - 1
    #return np.square(x) - np.square(np.pi)
    return np.square(x) - np.square(np.pi/2)

# %%
min_X = -8
max_X = 8
min_Y = -8
max_Y = 8
number_of_samples_of_domain = 160

# %%
x_label = 'x'
y_label = 'y'

# %%
plt.clf()
plt.close('all')
plt.axis([min_X, max_X, min_Y, max_Y])
ax = plt.gca()
ax.set_autoscale_on(False)
ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')

X = np.linspace(min_X, max_X, num=number_of_samples_of_domain)
X_points = []
Y = [f0(x) for x in X]
plt.plot(X, Y, 'b')

plt.xlabel(x_label)
plt.ylabel(y_label)
plt.show()

# %%
x7 = -6.4373
x8 = -0.860334
x9 = 3.42562
x10 = 9.52933

# %%
plt.clf()
plt.close('all')
plt.axis([min_X, max_X, min_Y, max_Y])
ax = plt.gca()
ax.set_autoscale_on(False)
ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')

X = np.linspace(min_X, max_X, num=number_of_samples_of_domain)
X_points = []
Y = [f0(x) for x in X]
plt.plot(X, Y, 'b')

plt.plot(x7, f0(x7), 'bo')
plt.plot(x8, f0(x8), 'bo')
plt.plot(x9, f0(x9), 'bo')
plt.plot(x10, f0(x10), 'bo')

plt.xlabel(x_label)
plt.ylabel(y_label)
plt.show()

# %%
min_X = -50
max_X = 50
min_Y = -50
max_Y = 50
number_of_samples_of_domain = 300

# %%
x_label = 'x'
y_label = 'y'

# %%
plt.clf()
plt.close('all')
plt.axis([min_X, max_X, min_Y, max_Y])
ax = plt.gca()
ax.set_autoscale_on(False)
ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')

X = np.linspace(min_X, max_X, num=number_of_samples_of_domain)
X_points = []
Y = [f0(x) for x in X]
plt.plot(X, Y, 'b')

plt.xlabel(x_label)
plt.ylabel(y_label)
plt.show()

# %%
plt.clf()
plt.close('all')
plt.axis([min_X, max_X, min_Y, max_Y])
ax = plt.gca()
ax.set_autoscale_on(False)
ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')

X = np.linspace(min_X, max_X, num=number_of_samples_of_domain)
X_points = []
Y = [f0(x) for x in X]
plt.plot(X, Y, 'b')

min_X = -8
max_X = 8
min_Y = -8
max_Y = 8
number_of_samples_of_domain = 160

plt.clf()
plt.close('all')
plt.axis([min_X, max_X, min_Y, max_Y])
ax = plt.gca()
ax.set_autoscale_on(False)
ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')

X = np.linspace(min_X, max_X, num=number_of_samples_of_domain)
X_points = []
Y = [f0(x) for x in X]
plt.plot(X, Y, 'b')

plt.plot(x7, f0(x7), 'bo')
plt.plot(x8, f0(x8), 'bo')
plt.plot(x9, f0(x9), 'bo')
plt.plot(x10, f0(x10), 'bo')

plt.xlabel(x_label)
plt.ylabel(y_label)
plt.show()

# %%
x2 = 3.42562

# %%
plt.clf()
plt.close('all')
plt.axis([min_X, max_X, min_Y, max_Y])
ax = plt.gca()
ax.set_autoscale_on(False)
ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.axvline(x=-4, color='gray')
ax.axvline(x=4, color='gray')

X = np.linspace(min_X, max_X, num=number_of_samples_of_domain)
X0 = []
X1 = []
X2 = []
for x in X:
    if x > -4 and x < 4:
        X2.append(x)
    elif x < -4:
        X0.append(x)
    else:
        X1.append(x)
Y = [f0(x) for x in X0]
plt.plot(X0, Y, 'r')
Y = [f0(x) for x in X1]
plt.plot(X1, Y, 'r')
Y = [f0(x) for x in X2]
plt.plot(X2, Y, 'b')

plt.plot(x2, f0(x2), 'go')

plt.xlabel(x_label)
plt.ylabel(y_label)
plt.show()

# %%
plt.clf()
plt.close('all')
plt.axis([min_X, max_X, min_Y, max_Y])
ax = plt.gca()
ax.set_autoscale_on(False)
ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.axvline(x=-2, color='gray')
ax.axvline(x=2, color='gray')

X = np.linspace(min_X, max_X, num=number_of_samples_of_domain)
Y = [f1(x) for x in X]
plt.plot(X, Y, 'black')
X0 = []
X1 = []
X2 = []
for x in X:
    if x > -2 and x < 2:
        X2.append(x)
    elif x < -2:
        X0.append(x)
    else:
        X1.append(x)
Y = [f0(x) for x in X0]
plt.plot(X0, Y, 'r')
Y = [f0(x) for x in X1]
plt.plot(X1, Y, 'r')
Y = [f0(x) for x in X2]
plt.plot(X2, Y, 'b')

plt.plot(2, f0(2), 'go')

plt.xlabel(x_label)
plt.ylabel(y_label)
plt.show()

# %%
x1 = -0.685174
x2 = 1.19836

x1 = -np.pi/2
x2 = np.pi/2

# %%
plt.clf()
plt.close('all')
plt.axis([min_X, max_X, min_Y, max_Y])
ax = plt.gca()
ax.set_autoscale_on(False)
ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')

X = np.linspace(min_X, max_X, num=number_of_samples_of_domain)
Y = [f2(x) for x in X]
plt.plot(X, Y, 'black')
X0 = []
X1 = []
X2 = []
for x in X:
    if x > -2 and x < 2:
        X2.append(x)
    elif x < -2:
        X0.append(x)
    else:
        X1.append(x)
Y = [f0(x) for x in X]
plt.plot(X, Y, 'r')
plt.plot(x1, f0(x1), 'bo')
plt.plot(x2, f0(x2), 'bo')

plt.xlabel(x_label)
plt.ylabel(y_label)
plt.show()

# %%
plt.clf()
plt.close('all')
# TODO need this?
#plt.figure(iteration)

plt.axis([min_X, max_X, min_Y, max_Y])
ax = plt.gca()
ax.set_autoscale_on(False)
ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')

X = np.linspace(min_X, max_X, num=number_of_samples_of_domain)
X_points = []
#for x in X:
#    new_point = Point(1, [x])
#    X_points.append(new_point)
#Y = [self.function.value_at(x) for x in X]
#Y = [self.function.value_at(x) for x in X_points]
Y = [f0(x) for x in X]
plt.plot(X, Y, 'b')
Y = [f1(x) for x in X]
plt.plot(X, Y, 'b')
Y = [f2(x) for x in X]
plt.plot(X, Y, 'r')

# not drawing 2D constraints in this version

#plt.plot(x_value_of_current_optimum, y_value_of_current_optimum, 'ro')
#for point in self.points:
   # plt.plot(point.get_value_at_dimension(0), self.function.value_at(point), 'ro')
plt.xlabel('x')
plt.ylabel('f(x)')
#plt.title('Title')
plt.show()

# %%
def f3(x):
    return np.square(x-3)

# %%
min_X = -4
max_X = 8
min_Y = -4
max_Y = 8
number_of_samples_of_domain = 160

# %%
plt.clf()
plt.close('all')
plt.axis([min_X, max_X, min_Y, max_Y])
ax = plt.gca()
ax.set_autoscale_on(False)
ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')

X = np.linspace(min_X, max_X, num=number_of_samples_of_domain)
X_points = []
Y = [f3(x) for x in X]
plt.plot(X, Y, 'b')

plt.plot(3, f3(3), 'go')

plt.xlabel(x_label)
plt.ylabel(y_label)
plt.show()

# %%
def f4(x):
    return np.square(np.square(x)) - np.square(x) + x/10

# %%
min_X = -2
max_X = 2
min_Y = -0.5
max_Y = 0.5
number_of_samples_of_domain = 160

# %%
x5 = -0.7389
x6 = 0.68064

# %%
plt.clf()
plt.close('all')
plt.axis([min_X, max_X, min_Y, max_Y])
ax = plt.gca()
ax.set_autoscale_on(False)
ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')

X = np.linspace(min_X, max_X, num=number_of_samples_of_domain)
X_points = []
Y = [f4(x) for x in X]
plt.plot(X, Y, 'b')

plt.plot(x5, f4(x5), 'go')
plt.plot(x6, f4(x6), 'bo')

plt.xlabel(x_label)
plt.ylabel(y_label)
plt.show()
